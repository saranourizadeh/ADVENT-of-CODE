# %%
##import libraries
import pandas as pd

# %%
input = pd.read_csv('./data/input.txt', header=None)

# %%
input[0].values
# Out:
# array(['sixsrvldfour4seven', '53hvhgchljnlxqjsgrhxgf1zfoureightmlhvvv',
#        'fives2dznl', 'twocrqvjsix5threethree',
#        'gtjtwonefourone6fouronefccmnpbpeightnine',
#        'seventdtrcseveneightsevencgjgjxfpmfsix8twones',
#        'fourthreeseven1grvhrjxklh3ninetwothree', 'fourninethrnnth8',
#        'two2hnxcfivejrdjxtb', 'bssbrgcx86vsmqstrxsjbjeightqzhbzxqg5',
#        'rsevenbqjfxh23rzdgcmdleightsixknpfs', 'jprxbcghdgxhk9x',
#        '8czzpmvgmlchnkf', 'vdrtteight85hlkninehgnblqnsdnineeight',
#        'fivetwohlxdql43kfzzbhtncg', 'lmhtwoneghgtl2',
#        'drtfsfhtbgfourpfpcznzrsix33', 'pptqkrdbeighteightsixdlsixkrlhr2',
#        '57threetwo', 'qoneight367gqbpbtbffivetlhrdjgnml2d',
#        'ninevdnzxsxone3', '3threeqzrmfndfiveeight4',
#        'rmthreethreefourtwotkpncxpmctkxjhzxg5',
#        'nsfrpl6lkqrrmlxhrxmngzjtzbpsjgeight', '9twobfknine57sixfour7',
#        '7one83sixthreecllxjnphb', '82nhxcjnck1', '5zrffive',
# ...

# %%
print(len(input))
# Out:
# 1000

# %%
#finding 2-digit-number in line
def digit(row):

    digit = ""

        #find first digit in line
    for i in range(len(row)):
        if row[i].isdigit():

            # print('first number found!')
            digit += row[i]
            break

    #to find last digit
    for j in range(len(row)-1, -1 , -1):

        if row[j].isdigit():
            # print('last digit found!')
            digit += row[j]
            break

    return digit

# %%
digit(input[0][1])
# Out:
# '51'

# %%
input[0][1]
# Out:
# '53hvhgchljnlxqjsgrhxgf1zfoureightmlhvvv'

# %%
sum = 0
for row in input[0]:
    # print(row)
    sum += int(digit(row))

print(sum)
# Out:
# 54561

# %%
def find_first_digit(row):
    for i in row:
        if i.isdigit():
            return i

# %%
find_first_digit('treb7uchet')
# Out:
# '7'

# %%
a = 'treb7uchet'

# %%
text = input.copy()[0].values

# %%
text
# Out:
# array(['sixsrvldfour4seven', '53hvhgchljnlxqjsgrhxgf1zfoureightmlhvvv',
#        'fives2dznl', 'twocrqvjsix5threethree',
#        'gtjtwonefourone6fouronefccmnpbpeightnine',
#        'seventdtrcseveneightsevencgjgjxfpmfsix8twones',
#        'fourthreeseven1grvhrjxklh3ninetwothree', 'fourninethrnnth8',
#        'two2hnxcfivejrdjxtb', 'bssbrgcx86vsmqstrxsjbjeightqzhbzxqg5',
#        'rsevenbqjfxh23rzdgcmdleightsixknpfs', 'jprxbcghdgxhk9x',
#        '8czzpmvgmlchnkf', 'vdrtteight85hlkninehgnblqnsdnineeight',
#        'fivetwohlxdql43kfzzbhtncg', 'lmhtwoneghgtl2',
#        'drtfsfhtbgfourpfpcznzrsix33', 'pptqkrdbeighteightsixdlsixkrlhr2',
#        '57threetwo', 'qoneight367gqbpbtbffivetlhrdjgnml2d',
#        'ninevdnzxsxone3', '3threeqzrmfndfiveeight4',
#        'rmthreethreefourtwotkpncxpmctkxjhzxg5',
#        'nsfrpl6lkqrrmlxhrxmngzjtzbpsjgeight', '9twobfknine57sixfour7',
#        '7one83sixthreecllxjnphb', '82nhxcjnck1', '5zrffive',
# ...

# %%
numbers = {'one': '1', 'two':'2',
           'three':'3', 'four':'4' ,
           'five':'5', 'six':'6',
           'seven':'7', 'eight':'8',
           'nine':'9'}

results = []
for i in text:
    row = i
    for key in numbers:
        row = row.replace(key, key + numbers[key] + key)
    # break


    results.append(row)

# %%
results
# Out:
# ['six6sixsrvldfour4four4seven7seven',
#  '53hvhgchljnlxqjsgrhxgf1zfour4foureight8eightmlhvvv',
#  'five5fives2dznl',
#  'two2twocrqvjsix6six5three3threethree3three',
#  'gtjtwo2twone1onefour4fourone1one6four4fourone1onefccmnpbpeight8eightnine9nine',
#  'seven7seventdtrcseven7seveneight8eightseven7sevencgjgjxfpmfsix6six8two2twone1ones',
#  'four4fourthree3threeseven7seven1grvhrjxklh3nine9ninetwo2twothree3three',
#  'four4fournine9ninethrnnth8',
#  'two2two2hnxcfive5fivejrdjxtb',
#  'bssbrgcx86vsmqstrxsjbjeight8eightqzhbzxqg5',
#  'rseven7sevenbqjfxh23rzdgcmdleight8eightsix6sixknpfs',
#  'jprxbcghdgxhk9x',
#  '8czzpmvgmlchnkf',
#  'vdrtteight8eight85hlknine9ninehgnblqnsdnine9nineeight8eight',
#  'five5fivetwo2twohlxdql43kfzzbhtncg',
#  'lmhtwo2twone1oneghgtl2',
#  'drtfsfhtbgfour4fourpfpcznzrsix6six33',
#  'pptqkrdbeight8eighteight8eightsix6sixdlsix6sixkrlhr2',
#  '57three3threetwo2two',
#  'qone1oneight8eight367gqbpbtbffive5fivetlhrdjgnml2d',
#  'nine9ninevdnzxsxone1one3',
# ...

# %%
# part 2

sum = 0
for row in results:
    first_digit = int(find_first_digit(row))
    second_digit = int(find_first_digit(row[::-1]))
    sum += 10*first_digit + second_digit

print(sum)
# Out:
# 54076

# %%
input[0][0].replace('six', '6')
# Out:
# '6srvldfour4seven'

# %%
numbers['one']
# Out:
# 1

# %%
text[0][100]
# Out:
# 'jlgvcn733'

# %%
##part 2
sum = 0
for row in text[0]:
    # print(row)
    sum += int(digit(row))

print(sum)
# Out:
# 53560

# %%
text[0][18]
# Out:
# '5732'

# %%
input[0][18]
# Out:
# '57threetwo'

# %%
digit(text[0][18])
# Out:
# '52'

# %%
numbers = {'one': '1', 'two':'2',
           'three':'3', 'four':'4' ,
           'five':'5', 'six':'6',
           'seven':'7', 'eight':'8',
           'nine':'9'}

# %%
[(i,j) for (i,j) in numbers.values()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [201], line 1
# ----> 1 [(i,j) for (i,j) in numbers.values()]
#
# Cell In [201], line 1, in <listcomp>(.0)
# ----> 1 [(i,j) for (i,j) in numbers.values()]
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
numbers
# Out:
# {'one': '1',
#  'two': '2',
#  'three': '3',
#  'four': '4',
#  'five': '5',
#  'six': '6',
#  'seven': '7',
#  'eight': '8',
#  'nine': '9'}

# %%
eightwothree
